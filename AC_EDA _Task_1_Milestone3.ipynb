# %%
#Anton Cizmok work - 
import pandas as pd

# %%
df = pd.read_csv('/Users/anton/desktop/DATA301/calendar.csv.gz')
df.head(10)
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0        3002  2022-12-16         f  $110.00        $110.00             4.0
# 1        3002  2022-12-17         t   $85.00         $85.00             4.0
# 2        3002  2022-12-18         f  $110.00        $110.00             4.0
# 3        3002  2022-12-19         f  $110.00        $110.00             4.0
# 4        3002  2022-12-20         f  $110.00        $110.00             4.0
# 5        3002  2022-12-21         f  $110.00        $110.00             4.0
# 6        3002  2022-12-22         t  $120.00        $120.00             4.0
# 7        3002  2022-12-23         f  $120.00        $120.00             4.0
# 8        3002  2022-12-24         f  $120.00        $120.00             4.0
# 9        3002  2022-12-25         f  $120.00        $120.00             4.0
#
#    maximum_nights
# 0             8.0
# 1             8.0
# 2             8.0
# 3             8.0
# 4             8.0
# ...

# %%
df = df.drop(['adjusted_price'], axis=1)
df
#adjusted price and price were seemingly the same - got rid of an unnecessary column
# Out:
#           listing_id        date available    price  minimum_nights  \
# 0               3002  2022-12-16         f  $110.00             4.0
# 1               3002  2022-12-17         t   $85.00             4.0
# 2               3002  2022-12-18         f  $110.00             4.0
# 3               3002  2022-12-19         f  $110.00             4.0
# 4               3002  2022-12-20         f  $110.00             4.0
# ...              ...         ...       ...      ...             ...
# 10973356       66919  2023-12-10         t  $795.00            30.0
# 10973357       66919  2023-12-11         t  $795.00            30.0
# 10973358       66919  2023-12-12         t  $795.00            30.0
# 10973359       66919  2023-12-13         t  $795.00            30.0
# 10973360       66919  2023-12-14         f  $795.00            30.0
#
#           maximum_nights
# 0                    8.0
# 1                    8.0
# 2                    8.0
# 3                    8.0
# ...

# %%
newdf = df.drop(df['maximum_nights'] < 4)
newdf
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:146, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:49, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'maximum_nights'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 newdf = df.drop(df['maximum_nights'] < 4)
# ...
